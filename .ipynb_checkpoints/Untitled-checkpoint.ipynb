# %%
x, y, z = 2, 3, 4

# %%
(x, y, z) == (4, 5, 6)
# Out:
# False

# %%
a, b = int(input('give a and b')), int(input('give a and b'))
# Out:
# give a and b2
# give a and b45

# %%
if a > b:
    z = a - b
elif a < b:
    z = b - a
else:
    z = 0
z
# Out:
# 2

# %%
list_ = str(range(7))
l = list_[:3]
r = list_[3:]

# %%
l[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-58ae4a033f40> in <module>
# ----> 1 l[2] = 'sike'
#
# TypeError: 'str' object does not support item assignment

# %%
def mergeSort(arr):
    if  len(arr) > 1:    
        m = len(arr) // 2
        L = arr[:m]
        R = arr[m:]
        mergeSort(L)
        mergeSort(R)
        
        i, j, k = 0, 0, 0
        while True:
            if L[i] < R[j]:
                arr[k] = L[i]
                i+=1
            else:
                arr[k] = R[j]
                j+=1
            k+=1
            
            if j < len(L):
                arr[k: k + len(R) - j] = R[j:]
                break
            if j == len(R):
                arr[k: k + len(L) - i] = L[i:]
                break

# %%
import operator


def merge(left, right, compare):
    result = []
    i, j = 0, 0
    while i < len(left) and j < len(right):
        if compare(left[i], right[j]):
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    if i < len(left):
        result.extend(left[i:])
    else:
        result.extend(right[j:])
    return result


def mergeSort(L, compare=operator.lt):
    if len(L) < 2:
        return L
    else:
        middle = int(len(L) / 2)
        left = mergeSort(L[:middle], compare)
        right = mergeSort(L[middle:], compare)
        return merge(left, right, compare)

# %%
import random
import time

arr =  [2,5,7,1,6,8,7,7,1,2,1,9]
current = time.time()
mergeSort(arr)
# Out:
# [1, 1, 1, 2, 2, 5, 6, 7, 7, 7, 8, 9]

# %%
def max_heapify(arr, index, size=len(arr)):
    left = 2 * index + 1
    right = 2 * index + 2
    largest = index
    if left < size and arr[largest] < arr[left]:
        largest = left
    if right < size and arr[largest] < arr[right]:
        largest = right
    if largest != index:
        arr[largest], arr[index] = arr[index], arr[largest]
        max_heapify(arr, largest)
    

    
    
def build_max_heap(arr):
    for i in range(len(arr)//2 - 1, -1, -1):
        max_heapify(arr, index=i)
        

def heap_sort(arr):
    build_max_heap(arr)
    heap_size = len(arr)
    while heap_size > 1:
        arr[0], arr[heap_size - 1] = arr[heap_size - 1], arr[0]
        max_heapify(arr, 0, size=heap_size)
        heap_size -= 1

# %%
arr =  [2,5,7,1,6,8,7,7,1,2,1,9]
build_max_heap(arr)
arr
# Out:
# [9, 7, 8, 5, 6, 7, 7, 1, 1, 2, 1, 2]

# %%
def mergeSort(arr): 
    if len(arr) >1: 
        mid = len(arr)//2 #Finding the mid of the array 
        L = arr[:mid] # Dividing the array elements  
        R = arr[mid:] # into 2 halves 
  
        mergeSort(L) # Sorting the first half 
        mergeSort(R) # Sorting the second half 
  
        i = j = k = 0
          
        # Copy data to temp arrays L[] and R[] 
        while i < len(L) and j < len(R): 
            if L[i] < R[j]: 
                arr[k] = L[i] 
                i+=1
            else: 
                arr[k] = R[j] 
                j+=1
            k+=1
          
        # Checking if any element was left 
        while i < len(L): 
            arr[k] = L[i] 
            i+=1
            k+=1
          
        while j < len(R): 
            arr[k] = R[j] 
            j+=1
            k+=1

# %%
arr =
for i, e in enumerate(arr[1:]):
    print(i, e)
# Out:
# 0 5
# 1 7
# 2 1
# 3 6
# 4 8
# 5 7
# 6 7
# 7 1
# 8 2

# %%
lis = [15.5, 14, 10, 15.5, 16, 9.75, 10, 11.5, 7, 11, 15, 18, 0, 12, 11.5, 14, 14.5, 11, 10, 13.5, 13.5, 17, 17, 16, 14, 10.5, 15, 15.5, 13, 0, 0]

# %%
len(lis)
# Out:
# 31

# %%
sum(lis)/len(lis)
# Out:
# 11.975806451612904

# %%
import numpy as np
arr = np.array(lis)

# %%
arr.mean()
# Out:
# 12.801724137931034

# %%
dir(arr)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_interface__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lshift__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
# ...

# %%
x = [12.5 , 16 , 9.5 , 13.5 , 11 , 16.5 , 12 , 13 , 11 , 9 , 10 , 10 , 13 , 14 , 10.5 , 10 , 13 , 10.5 , 14 , 15 , 15 , 18 , 16 , 20 , 15.5 , 15 , 11 , 14]

# %%
len(x)
# Out:
# 28

# %%
import numpy as np

np.mean(x)
# Out:
# 13.160714285714286

# %%
list_ = list(range(7))
def foo(list_):
    return list_.append(999)

list2 = foo(list_)
list_
# Out:
# [0, 1, 2, 3, 4, 5, 6, 999]

# %%
list_ = [5, 6, 7, 8]
for e in list_:
    print(id(e))
# Out:
# 1453097136
# 1453097168
# 1453097200
# 1453097232

# %%
a = 2
b = (5,6)
c = {4}

list_ = [a, b, c]
print(id(a))
print(id(b))
print(id(c))

for e in list_:
    print(id(e))
# Out:
# 1453097040
# 2376767459272
# 2376768199592
# 1453097040
# 2376767459272
# 2376768199592

# %%
list_ = [2, {5,6}, 'h']
for e in list_:
    print(id(e))
# Out:
# 1453097040
# 2376742860616
# 2376696898368

# %%
a = 2
b = (5,6)
c = {4}

list_ = [a, b, c]
list_[0] is a
# Out:
# True

# %%
import operator
from time import time


def merge(left, right, compare):
    result = []
    i, j = 0, 0
    while i < len(left) and j < len(right):
        if compare(left[i], right[j]):
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    while i < len(left):
        result.append(left[i])
        i += 1
    while j < len(right):
        result.append(right[j])
        j += 1
    return result


def mergeSort(L, compare=operator.lt):
    if len(L) < 2:
        return L[:]
    else:
        middle = int(len(L) / 2)
        left = mergeSort(L[:middle], compare)
        right = mergeSort(L[middle:], compare)
        return merge(left, right, compare)

# %%
current = time()
print(mergeSort([1,2,7,6,8,4,5,6,2,1,4,78], 0, 11))
time() - current
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-3ab5d0c0d4ac> in <module>
#       1 current = time()
# ----> 2 print(mergeSort([1,2,7,6,8,4,5,6,2,1,4,78], 0, 11))
#       3 time() - current
#
# <ipython-input-10-6abdaf0186fc> in mergeSort(Arr, start, end)
#      38         if(start < end) :
#      39                 mid = (start + end) / 2
# ---> 40                 mergeSort(Arr, start, mid)
#      41                 mergeSort(Arr, mid+1, end)
#      42                 merge(Arr, start, mid, end)
#
# <ipython-input-10-6abdaf0186fc> in mergeSort(Arr, start, end)
#      38         if(start < end) :
#      39                 mid = (start + end) / 2
# ---> 40                 mergeSort(Arr, start, mid)
#      41                 mergeSort(Arr, mid+1, end)
#      42                 merge(Arr, start, mid, end)
#
# ...

# %%
def merge(Arr, start, mid, end) :

	# create a temp array
	temp = [0] * (end - start + 1)

	# crawlers for both intervals and for temp
	i, j, k = start, mid+1, 0

	# traverse both lists and in each iteration add smaller of both elements in temp 
	while(i <= mid and j <= end) :
		if(Arr[i] <= Arr[j]) :
			temp[k] = Arr[i]
			k += 1; i += 1
		else :
			temp[k] = Arr[j]
			k += 1; j += 1

	# add elements left in the first interval 
	while(i <= mid):
		temp[k] = Arr[i]
		k += 1; i += 1

	# add elements left in the second interval 
	while(j <= end):
		temp[k] = Arr[j]
		k += 1; j += 1

	# copy temp to original interval
	for i in range(start, end + 1):
		Arr[i] = temp[i - start]


# Arr is an array of integer type
# start and end are the starting and ending index of current interval of Arr

def mergeSort(Arr, start, end):

	if(start < end) :
		mid = (start + end) / 2
		mergeSort(Arr, start, mid)
		mergeSort(Arr, mid+1, end)
		merge(Arr, start, mid, end)
